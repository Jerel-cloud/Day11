# %% [raw]
# ## Introduction to Data Science
#
# #### University of Redlands - DATA 101
# #### Prof: Joanna Bieri [joanna_bieri@redlands.edu](mailto:joanna_bieri@redlands.edu)
# #### [Class Website: data101.joannabieri.com](https://joannabieri.com/data101.html)
#
# ---------------------------------------
# # Homework Day 11
# ---------------------------------------
#
# GOALS:
#
# 1. Understand Causal vs Experimental Studies
# 2. Do a more free form data analysis
# 3. Start doing your ethics reading
#
# ----------------------------------------------------------
#
# This homework has **2 questions**, **10 exercises** and **1 essay response**.

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import plotly.express as px
from plotly.subplots import make_subplots
import plotly.io as pio
pio.renderers.defaule = 'colab'

from itables import show

# This stops a few warning messages from showing
pd.options.mode.chained_assignment = None 
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
file_name = 'data/yougov-climate.csv'
DF = pd.read_csv(file_name,index_col=0)
DF
# Out:
#          The climate is changing and human activity is mainly responsible    \
# country
# GB                                                     833
# US                                                     507
#
#          The climate is changing and human activity is partly responsible, together with other factors    \
# country
# GB                                                     604
# US                                                     493
#
#          The climate is changing but human activity is not responsible at all    \
# country
# GB                                                      49
# US                                                     120
#
#          The climate is not changing    Don't know
# country
# GB                                  33         114
# US                                  80         133

# %% [markdown]
# In the lecture we analyzed the following questions for the first column in the data:
#
# ### First question:
#
# What percent of **all respondents** think the climate is changing and human activity is mainly responsible?
#
# ### Second question:
#
# What percent of **GB respondents** think the climate is changing and  human activity is mainly responsible?
#
# ### Third Question
#
# What percent of **US respondents** think the climate is changing and  human activity is mainly responsible?
#
# **Q1** Repeat the analysis from the lecture notes for one of the other columns/questions.
#
# 1. Percent total
# 2. Percent from GB
# 3. Percent from US
#
# Talk about the conditional probability in this case:
#
# eg. In a person is from ________ then there is a ________ probability that they believe _______. If a person answered _______ then they are more likley to be from ________.

# %%
DF.loc['total']= DF.sum(axis=0)
DF['total'] = DF.sum(axis=1)
DF
# Out:
#          The climate is changing and human activity is mainly responsible    \
# country
# GB                                                     833
# US                                                     507
# total                                                 1340
#
#          The climate is changing and human activity is partly responsible, together with other factors    \
# country
# GB                                                     604
# US                                                     493
# total                                                 1097
#
#          The climate is changing but human activity is not responsible at all    \
# country
# GB                                                      49
# US                                                     120
# total                                                  169
#
#          The climate is not changing    Don't know  total
# country
# GB                                  33         114   1633
# US                                  80         133   1333
# total                              113         247   2966

# %%
all_respondents = DF['total'].loc['total']
humans_responsible = DF['The climate is changing and human activity is mainly responsible  '].loc['total']
humans_responsible/all_respondents
# Out:
# 0.45178691840863117

# %%
GB_respondents = DF['total'].loc['GB']
GB_responsible = DF['The climate is changing and human activity is mainly responsible  '].loc['GB']
GB_responsible/GB_respondents
# Out:
# 0.5101041028781383

# %%
US_respondents = DF['total'].loc['US']
US_responsible = DF['The climate is changing and human activity is mainly responsible  '].loc['US']
US_responsible/US_respondents
# Out:
# 0.3803450862715679

# %% [markdown]
# 1. The percent of all respondents who think that climate is changing and human activity is mainly responsible is around 45.2%.
# 2. The percent of GB respondents who think that climate is changing and human activity is mainly responsible is around 51%.
# 3. The percent of US respondents who think that climate is changing and human activity is mainly responsible is around 38%.
# 4. In a person is from US then there is a 38% probability that they believe that the climate is changing and human activity is mainly responsible. If a person answered yes then they are more likley to be from GB.

# %% [markdown]
# ## Berkeley admission data example
#
# - Study carried out by the Graduate Division of the University of California, Berkeley in the early 70’s to evaluate whether there was a gender bias in graduate admissions.
# - The data come from six departments. For confidentiality we'll call them A-F.
# - We have information on whether the applicant was male or female and whether they were admitted or rejected. This is an old study so only two binary classifications were used.
#
# ### Here is the data

# %%
file_name = 'data/berkley.csv'
DF = pd.read_csv(file_name)
show(DF)
# Out:
# <table id="itables_f204a361_80f1_47e1_823c_8ae39ae95a10" class="display nowrap" data-quarto-disable-processing="true" style="table-layout:auto;width:auto;margin:auto;caption-side:bottom">
# <thead>
#     <tr style="text-align: right;">
#
#       <th>Department</th>
#       <th>Male Yes</th>
#       <th>Male No</th>
#       <th>Female Yes</th>
#       <th>Female No</th>
#     </tr>
#   </thead><tbody><tr>
# <td style="vertical-align:middle; text-align:left">
# <div style="float:left; margin-right: 10px;">
# <a href=https://mwouts.github.io/itables/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:#d9d7fc">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:#1a1366;stroke:#1a1366;">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
# </div>
# <div>
# Loading ITables v2.1.5 from the internet...
# (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td>
# </div>
# </tr></tbody>
#
# </table>
# <link href="https://www.unpkg.com/dt_for_itables@2.0.12/dt_bundle.css" rel="stylesheet">
# <script type="module">
#     import {DataTable, jQuery as $} from 'https://www.unpkg.com/dt_for_itables@2.0.12/dt_bundle.js';
#
#     document.querySelectorAll("#itables_f204a361_80f1_47e1_823c_8ae39ae95a10:not(.dataTable)").forEach(table => {
#         // Define the table data
#         const data = [["A", 512, 313, 89, 19], ["B", 353, 207, 17, 8], ["C", 120, 205, 202, 391], ["D", 138, 279, 131, 244], ["E", 53, 138, 94, 299], ["F", 22, 351, 24, 317]];
#
#         // Define the dt_args
#         let dt_args = {"layout": {"topStart": null, "topEnd": null, "bottomStart": null, "bottomEnd": null}, "order": []};
#         dt_args["data"] = data;
#
#
#         new DataTable(table, dt_args);
#     });
# </script>

# %%
DF_melt = pd.melt(DF,id_vars=['Department'],var_name='MF',value_name='Number')
DF_melt
# Out:
#    Department          MF  Number
# 0           A    Male Yes     512
# 1           B    Male Yes     353
# 2           C    Male Yes     120
# 3           D    Male Yes     138
# 4           E    Male Yes      53
# 5           F    Male Yes      22
# 6           A     Male No     313
# 7           B     Male No     207
# 8           C     Male No     205
# 9           D     Male No     279
# 10          E     Male No     138
# 11          F     Male No     351
# 12          A  Female Yes      89
# 13          B  Female Yes      17
# 14          C  Female Yes     202
# 15          D  Female Yes     131
# 16          E  Female Yes      94
# 17          F  Female Yes      24
# 18          A   Female No      19
# 19          B   Female No       8
# 20          C   Female No     391
# 21          D   Female No     244
# 22          E   Female No     299
# 23          F   Female No     317

# %%
DF_melt['gender'] = DF_melt['MF'].apply(lambda x: x.split(' ')[0]).copy()
DF_melt['admitted'] = DF_melt['MF'].apply(lambda x: x.split(' ')[1]).copy()

# %%
DF_melt
# Out:
#    Department          MF  Number  gender admitted
# 0           A    Male Yes     512    Male      Yes
# 1           B    Male Yes     353    Male      Yes
# 2           C    Male Yes     120    Male      Yes
# 3           D    Male Yes     138    Male      Yes
# 4           E    Male Yes      53    Male      Yes
# 5           F    Male Yes      22    Male      Yes
# 6           A     Male No     313    Male       No
# 7           B     Male No     207    Male       No
# 8           C     Male No     205    Male       No
# 9           D     Male No     279    Male       No
# 10          E     Male No     138    Male       No
# 11          F     Male No     351    Male       No
# 12          A  Female Yes      89  Female      Yes
# 13          B  Female Yes      17  Female      Yes
# 14          C  Female Yes     202  Female      Yes
# 15          D  Female Yes     131  Female      Yes
# 16          E  Female Yes      94  Female      Yes
# 17          F  Female Yes      24  Female      Yes
# 18          A   Female No      19  Female       No
# 19          B   Female No       8  Female       No
# 20          C   Female No     391  Female       No
# 21          D   Female No     244  Female       No
# 22          E   Female No     299  Female       No
# 23          F   Female No     317  Female       No

# %% [markdown]
# ### Gender distribution by department
#
# What can we say about the gender distribution if we look at the individual departments.
#
# Start with our original "melted" data frame:

# %% [markdown]
# #### Lets pivot!
#
# Pivot this data so that our departments become the column labels and our MF column becomes the index.

# %%
# Your code here
DF_dept = DF_melt.pivot(index='MF', columns='Department', values='Number')
DF_dept
# Out:
# Department    A    B    C    D    E    F
# MF
# Female No    19    8  391  244  299  317
# Female Yes   89   17  202  131   94   24
# Male No     313  207  205  279  138  351
# Male Yes    512  353  120  138   53   22

# %% [markdown]
# **Q2** Calculate the proportions for the other departments. We did department A in the lecture. You can use the code from the lecture or come up with your own way to do this. You can do this one by one or try using a FOR loop.
#
# Talk about what you see in these proportions. Which departments admit a large number of women? How do your number align with the visualization below?

# %% [markdown]
# 1. Department A has the highest probability at admitting women.

# %%
# Your code here
prob_female_A = DF_dept['A']['Female Yes']/(DF_dept['A']['Female Yes']+DF_dept['A']['Female No'])
prob_male_A = DF_dept['A']['Male Yes']/(DF_dept['A']['Male Yes']+DF_dept['A']['Male No'])

prob_female_B = DF_dept['B']['Female Yes']/(DF_dept['B']['Female Yes']+DF_dept['B']['Female No'])
prob_male_B = DF_dept['B']['Male Yes']/(DF_dept['B']['Male Yes']+DF_dept['B']['Male No'])

prob_female_C = DF_dept['C']['Female Yes']/(DF_dept['C']['Female Yes']+DF_dept['C']['Female No'])
prob_male_C = DF_dept['C']['Male Yes']/(DF_dept['C']['Male Yes']+DF_dept['C']['Male No'])

prob_female_D= DF_dept['D']['Female Yes']/(DF_dept['D']['Female Yes']+DF_dept['D']['Female No'])
prob_male_D = DF_dept['D']['Male Yes']/(DF_dept['D']['Male Yes']+DF_dept['D']['Male No'])

prob_female_E = DF_dept['E']['Female Yes']/(DF_dept['E']['Female Yes']+DF_dept['E']['Female No'])
prob_male_E = DF_dept['E']['Male Yes']/(DF_dept['E']['Male Yes']+DF_dept['E']['Male No'])

prob_female_F = DF_dept['F']['Female Yes']/(DF_dept['F']['Female Yes']+DF_dept['F']['Female No'])
prob_male_F = DF_dept['F']['Male Yes']/(DF_dept['F']['Male Yes']+DF_dept['F']['Male No'])

# %%
prob_female_A
# Out:
# 0.8240740740740741

# %%
prob_female_B
# Out:
# 0.68

# %%
prob_female_C
# Out:
# 0.3406408094435076

# %%
prob_female_D
# Out:
# 0.34933333333333333

# %%
prob_female_E
# Out:
# 0.23918575063613232

# %%
prob_female_F
# Out:
# 0.07038123167155426

# %% [markdown]
# ### Here is a plot of the proportions data

# %%
fig = px.histogram(DF_melt,
                   y='gender',
                   x='Number',
                   barnorm = "percent",
                   color='admitted',
                   facet_col='Department',
                   facet_col_wrap=2,
                   color_discrete_map = {'No':'#99d8c9','Yes':'#2ca25f'})

fig.for_each_annotation(lambda a: a.update(text=a.text.split("=")[1]))
fig.update_xaxes(title_text='')

fig.update_layout(title='Percent male and female applications',
                  title_x=0.5,
                  template="plotly_white",
                  xaxis_title="",
                  yaxis_title="Gender",
                  legend_title='Admitted',
                  autosize=False,
                  width=800,
                  height=500)

fig.show()

# %% [markdown]
# ------------------------
# ------------------------
#
# ## Homework - Exercises
#
# ** Homework content and data from Data Science in a Box - he-05-legos.Rmd
#
# This week we'll do some data gymnastics to refresh and review what we learned over the past few weeks using (**simulated**) data from Lego sales in 2018 for a sample of customers who bought Legos in the US. This is different than the data we used on the Exam!
#
#
# ### Data

# %%
file_name = 'data/lego-sales.csv'
DF = pd.read_csv(file_name)
DF
# Out:
#     first_name  last_name  age  phone_number  set_id   number  \
# 0     Kimberly  Beckstead   24  216-555-2549   24701    76062
# 1         Neel     Garvin   35  819-555-3189   25626    70595
# 2         Neel     Garvin   35  819-555-3189   24665    21031
# 3      Chelsea   Bouchard   41           NaN   24695    31048
# 4      Chelsea   Bouchard   41           NaN   25626    70595
# ..         ...        ...  ...           ...     ...      ...
# 615     Talise   Nieukirk   16  801-555-2343   24902    41556
# 616    Spencer     Morgan   28  784-555-3455   26041    41580
# 617    Spencer     Morgan   28  784-555-3455   26060  5005051
# 618     Amelia    Hageman   40  336-555-1950   24702    76063
# 619     Amelia    Hageman   40  336-555-1950   24720    10830
#
#                       theme              subtheme  year  \
# 0    DC Comics Super Heroes         Mighty Micros  2018
# 1                   Ninjago  Rise of the Villains  2018
# 2              Architecture                   NaN  2018
# 3                   Creator                   NaN  2018
# 4                   Ninjago  Rise of the Villains  2018
# ..                      ...                   ...   ...
# 615                  Mixels              Series 7  2018
# 616                  Mixels              Series 9  2018
# 617                    Gear         Digital Media  2018
# 618  DC Comics Super Heroes         Mighty Micros  2018
# 619                   Duplo                   NaN  2018
#
#                                        name  pieces  us_price  \
# 0                            Robin vs. Bane    77.0      9.99
# 1                      Ultra Stealth Raider  1093.0    119.99
# 2                              Burj Khalifa   333.0     39.99
# 3                            Lakeside Lodge   368.0     29.99
# 4                      Ultra Stealth Raider  1093.0    119.99
# ..                                      ...     ...       ...
# 615                                  Tiketz    62.0      4.99
# 616                                    Myke    63.0      4.99
# 617  Friends of Heartlake City Girlz 4 Life     NaN     19.99
# 618              The Flash vs. Captain Cold    88.0      9.99
# 619                           Minnie's Café    27.0     19.99
#
#                                              image_url  quantity
# 0    http://images.brickset.com/sets/images/76062-1...         1
# 1    http://images.brickset.com/sets/images/70595-1...         1
# 2    http://images.brickset.com/sets/images/21031-1...         1
# 3    http://images.brickset.com/sets/images/31048-1...         1
# 4    http://images.brickset.com/sets/images/70595-1...         1
# ..                                                 ...       ...
# 615  http://images.brickset.com/sets/images/41556-1...         2
# 616                                                NaN         2
# 617                                                NaN         1
# 618  http://images.brickset.com/sets/images/76063-1...         2
# 619  http://images.brickset.com/sets/images/10830-1...         4
#
# [620 rows x 14 columns]

# %%
DF.shape
# Out:
# (620, 14)

# %%
show(DF['first_name'].value_counts())
# Out:
# <table id="itables_bf2fc6b5_a4cb_460c_90f7_c3d9b7c14741" class="display nowrap" data-quarto-disable-processing="true" style="table-layout:auto;width:auto;margin:auto;caption-side:bottom">
# <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>count</th>
#     </tr>
#     <tr>
#       <th>first_name</th>
#       <th></th>
#     </tr>
#   </thead><tbody><tr>
# <td style="vertical-align:middle; text-align:left">
# <div style="float:left; margin-right: 10px;">
# <a href=https://mwouts.github.io/itables/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:#d9d7fc">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:#1a1366;stroke:#1a1366;">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
# </div>
# <div>
# Loading ITables v2.1.5 from the internet...
# (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td>
# </div>
# </tr></tbody>
#
# </table>
# <link href="https://www.unpkg.com/dt_for_itables@2.0.12/dt_bundle.css" rel="stylesheet">
# <script type="module">
#     import {DataTable, jQuery as $} from 'https://www.unpkg.com/dt_for_itables@2.0.12/dt_bundle.js';
#
#     document.querySelectorAll("#itables_bf2fc6b5_a4cb_460c_90f7_c3d9b7c14741:not(.dataTable)").forEach(table => {
#         // Define the table data
#         const data = [["Jackson", 13], ["Joseph", 11], ["Jacob", 11], ["Michael", 10], ["Kaitlyn", 8], ["Lucas", 8], ["Connor", 8], ["Audrey", 8], ["Amanda", 7], ["Joshua", 7], ["Spencer", 6], ["Josie", 6], ["Katherine", 6], ["Sarah", 6], ["Paige", 6], ["Krista", 5], ["Trevor", 5], ["Caroline", 5], ["Celia", 5], ["Alina", 5], ["Austin", 5], ["Tristin", 5], ["Abraham", 5], ["India", 5], ["Saige", 5], ["John", 5], ["Ramses", 5], ["Nicholas", 5], ["Brandilyn", 5], ["Daniel", 5], ["Brian
ait", 1], ["Asia", 1], ["Keno", 1], ["Trevon", 1], ["Elaine", 1], ["Justin", 1], ["Allison", 1], ["Gabrielle", 1], ["Rachelle", 1], ["George", 1], ["Alejandre", 1], ["Darian", 1], ["Brenden", 1], ["Van", 1], ["Kareena", 1], ["Dominic", 1], ["Keith", 1], ["Sonny", 1], ["Aleksandr", 1], ["Gunnar", 1], ["David", 1], ["Lawrence", 1], ["John'Dunae", 1], ["Kimberly", 1]];
#
#         // Define the dt_args
#         let dt_args = {"layout": {"topStart": "pageLength", "topEnd": "search", "bottomStart": "info", "bottomEnd": "paging"}, "order": []};
#         dt_args["data"] = data;
#
#
#         new DataTable(table, dt_args);
#     });
# </script>

# %%
show(DF['theme'].value_counts())
# Out:
# <table id="itables_db041d83_9a86_4ac3_bc68_fd5fea14e009" class="display nowrap" data-quarto-disable-processing="true" style="table-layout:auto;width:auto;margin:auto;caption-side:bottom">
# <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>count</th>
#     </tr>
#     <tr>
#       <th>theme</th>
#       <th></th>
#     </tr>
#   </thead><tbody><tr>
# <td style="vertical-align:middle; text-align:left">
# <div style="float:left; margin-right: 10px;">
# <a href=https://mwouts.github.io/itables/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:#d9d7fc">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:#1a1366;stroke:#1a1366;">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
# </div>
# <div>
# Loading ITables v2.1.5 from the internet...
# (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td>
# </div>
# </tr></tbody>
#
# </table>
# <link href="https://www.unpkg.com/dt_for_itables@2.0.12/dt_bundle.css" rel="stylesheet">
# <script type="module">
#     import {DataTable, jQuery as $} from 'https://www.unpkg.com/dt_for_itables@2.0.12/dt_bundle.js';
#
#     document.querySelectorAll("#itables_db041d83_9a86_4ac3_bc68_fd5fea14e009:not(.dataTable)").forEach(table => {
#         // Define the table data
#         const data = [["Star Wars", 75], ["Nexo Knights", 64], ["Gear", 55], ["Mixels", 55], ["City", 45], ["Friends", 42], ["Ninjago", 38], ["Duplo", 35], ["Bionicle", 34], ["Creator", 25], ["DC Comics Super Heroes", 22], ["Elves", 22], ["Marvel Super Heroes", 19], ["Dimensions", 18], ["Disney Princess", 15], ["The Angry Birds Movie", 11], ["Technic", 10], ["Architecture", 10], ["Minecraft", 9], ["Advanced Models", 4], ["Ghostbusters", 3], ["Seasonal", 3], ["Collectable Minifigures", 3], ["Ideas", 2], ["Classic", 1]];
#
#         // Define the dt_args
#         let dt_args = {"layout": {"topStart": "pageLength", "topEnd": "search", "bottomStart": "info", "bottomEnd": "paging"}, "order": []};
#         dt_args["data"] = data;
#
#
#         new DataTable(table, dt_args);
#     });
# </script>

# %%
mask = DF['age'] <= 18
DF[mask]
# Out:
#     first_name          last_name  age  phone_number  set_id   number  \
# 44    Michelle          Uguccioni   17           NaN   24756    70310
# 45    Michelle          Uguccioni   17           NaN   24896    31046
# 70       Lucas  Jimenez-Dominguez   18  712-555-0459   24691    31043
# 71       Lucas  Jimenez-Dominguez   18  712-555-0459   26034    41573
# 72       Lucas  Jimenez-Dominguez   18  712-555-0459   24704    41140
# 73       Lucas  Jimenez-Dominguez   18  712-555-0459   24903    41558
# 74       Lucas  Jimenez-Dominguez   18  712-555-0459   26033    41572
# 187   Chayanne           Williams   17  869-555-6681   24678    60109
# 188   Chayanne           Williams   17  869-555-6681   24697    76044
# 223    Michael               Cruz   17  361-555-8212   24723    41172
# 224    Michael               Cruz   17  361-555-8212   24618    71238
# 225    Michael               Cruz   17  361-555-8212   24920    70605
# 284     Steven         Washington   16  336-555-1433   25910    30347
# 285     Steven         Washington   16  336-555-1433   25893    30349
# 286     Serena         Bartkowiak   16  305-555-2377   24806    71311
# 287     Serena         Bartkowiak   16  305-555-2377   24778    75113
# 288     Serena         Bartkowiak   16  305-555-2377   24987    40201
# 439      Aaron             Bruner   18  914-555-5003   24679    60111
# 440      Aaron             Bruner   18  914-555-5003   24956    71300
# 441      Aaron             Bruner   18  914-555-5003   24796    75137
# 443    Michael             Donner   18  432-555-3069   24660    71241
# 444    Michael             Donner   18  432-555-3069   24709    10803
# 445    Michael             Donner   18  432-555-3069   26059  5005060
# 476      Dylan            Mcgrath   18  229-555-1970   24748    76050
# 477      Dylan            Mcgrath   18  229-555-1970   25645    71314
# 611    Natalia           Vonduyke   16  859-555-3818   25879   853534
# 612    Natalia           Vonduyke   16  859-555-3818   24714    10814
# 73   http://images.brickset.com/sets/images/41558-1...         2
# 74                                                 NaN         1
# 187  http://images.brickset.com/sets/images/60109-1...         2
# 188  http://images.brickset.com/sets/images/76044-1...         1
# 223  http://images.brickset.com/sets/images/41172-1...         1
# 224  http://images.brickset.com/sets/images/71238-1...         1
# 225  http://images.brickset.com/sets/images/70605-1...         1
# 284  http://images.brickset.com/sets/images/30347-1...         1
# 285  http://images.brickset.com/sets/images/30349-1...         5
# 286  http://images.brickset.com/sets/images/71311-1...         2
# 287  http://images.brickset.com/sets/images/75113-1...         1
# 288  http://images.brickset.com/sets/images/40201-1...         1
# 439  http://images.brickset.com/sets/images/60111-1...         4
# 440  http://images.brickset.com/sets/images/71300-1...         1
# 441  http://images.brickset.com/sets/images/75137-1...         2
# 443  http://images.brickset.com/sets/images/71241-1...         2
# 444  http://images.brickset.com/sets/images/10803-1...         1
# 445  http://images.brickset.com/sets/images/5005060...         1
# 476  http://images.brickset.com/sets/images/76050-1...         1
# 477                                                NaN         1
# 611  http://images.brickset.com/sets/images/853534-...         2
# 612  http://images.brickset.com/sets/images/10814-1...         1
# 613  http://images.brickset.com/sets/images/70332-1...         1
# 614  http://images.brickset.com/sets/images/75149-1...         1
# 615  http://images.brickset.com/sets/images/41556-1...         2

# %%
DF_group = DF[mask].copy()

# %%
mask2 = (DF['age'] >= 19) & (DF['age'] <= 25)
DF[mask2]
# Out:
#     first_name    last_name  age  phone_number  set_id number  \
# 0     Kimberly    Beckstead   24  216-555-2549   24701  76062
# 6      Bryanna        Welsh   19           NaN   24797  75138
# 7      Bryanna        Welsh   19           NaN   24701  76062
# 10       Chase  Fortenberry   19  205-555-3704   24707  10801
# 11       Chase  Fortenberry   19  205-555-3704   24713  10809
# ..         ...          ...  ...           ...     ...    ...
# 591      Paige          Ice   21           NaN   26038  41577
# 592      Aiden       Ganley   19  786-555-5067   25639  70324
# 593      Aiden       Ganley   19  786-555-5067   24756  70310
# 608    Carolyn       Quarry   23  567-555-7649   25627  70596
# 609    Carolyn       Quarry   23  567-555-7649   24806  71311
#
#                       theme              subtheme  year  \
# 0    DC Comics Super Heroes         Mighty Micros  2018
# 6                 Star Wars             Episode V  2018
# 7    DC Comics Super Heroes         Mighty Micros  2018
# 10                    Duplo                   NaN  2018
# 11                    Duplo                   NaN  2018
# ..                      ...                   ...   ...
# 591                  Mixels              Series 9  2018
# 592            Nexo Knights                   NaN  2018
# 593            Nexo Knights                   NaN  2018
# 608                 Ninjago  Rise of the Villains  2018
# 609                Bionicle         Miscellaneous  2018
#
#                              name  pieces  us_price  \
# 0                  Robin vs. Bane    77.0      9.99
# 6                     Hoth Attack   233.0     24.99
# 7                  Robin vs. Bane    77.0      9.99
# 10                   Baby Animals    13.0      9.99
# 11                  Police Patrol    15.0     14.99
# ..                            ...     ...       ...
# 591                         Mysto    64.0      4.99
# 592          Merlok's Library 2.0   288.0     24.99
# 593       Knighton Battle Blaster    76.0      9.99
# 608          Samurai X Cave Chaos  1253.0    119.99
# 609  Kopaka and Melum - Unity set   171.0     24.99
#
#                                              image_url  quantity
# 0    http://images.brickset.com/sets/images/76062-1...         1
# 6    http://images.brickset.com/sets/images/75138-1...         1
# 7    http://images.brickset.com/sets/images/76062-1...         3
# 10   http://images.brickset.com/sets/images/10801-1...         1
# 11   http://images.brickset.com/sets/images/10809-1...         1
# ..                                                 ...       ...
# 591                                                NaN         1
# 592  http://images.brickset.com/sets/images/70324-1...         1
# 593  http://images.brickset.com/sets/images/70310-1...         2
# 608                                                NaN         2
# 609  http://images.brickset.com/sets/images/71311-1...         2
#
# [129 rows x 14 columns]

# %%
mask3 = (DF['age'] >= 26) & (DF['age'] <= 35)
DF[mask3]
# Out:
#     first_name  last_name  age  phone_number  set_id   number         theme  \
# 1         Neel     Garvin   35  819-555-3189   25626    70595       Ninjago
# 2         Neel     Garvin   35  819-555-3189   24665    21031  Architecture
# 27       Jacob  Nzabanita   31  339-555-2572   24732    41117       Friends
# 28       Jacob  Nzabanita   31  339-555-2572   24793    75133     Star Wars
# 29       Jacob  Nzabanita   31  339-555-2572   24723    41172         Elves
# ..         ...        ...  ...           ...     ...      ...           ...
# 606   Benjamin       Park   33           NaN   24957    71309      Bionicle
# 607      Miles       Hill   34           NaN   24758    70312  Nexo Knights
# 610   Jennifer    Reinert   29  402-555-0467   24660    71241    Dimensions
# 616    Spencer     Morgan   28  784-555-3455   26041    41580        Mixels
# 617    Spencer     Morgan   28  784-555-3455   26060  5005051          Gear
#
#                  subtheme  year                                    name  \
# 1    Rise of the Villains  2018                    Ultra Stealth Raider
# 2                     NaN  2018                            Burj Khalifa
# 27               Pop Star  2018                      Pop Star TV Studio
# 28            Battlefront  2018              Rebel Alliance Battle Pack
# 29                    NaN  2018              The Water Dragon Adventure
# ..                    ...   ...                                     ...
# 606                   Toa  2018                  Onua - Uniter of Earth
# 607                   NaN  2018                     Lance's Mecha Horse
# 610              Fun Pack  2018                        Fun Pack: Slimer
# 616              Series 9  2018                                    Myke
# 617         Digital Media  2018  Friends of Heartlake City Girlz 4 Life
#
#      pieces  us_price                                          image_url  \
# 1    1093.0    119.99  http://images.brickset.com/sets/images/70595-1...
# 2     333.0     39.99  http://images.brickset.com/sets/images/21031-1...
# 27    194.0     19.99  http://images.brickset.com/sets/images/41117-1...
# 28    101.0     12.99  http://images.brickset.com/sets/images/75133-1...
# 29    212.0     19.99  http://images.brickset.com/sets/images/41172-1...
# ..      ...       ...                                                ...
# 606   143.0     19.99  http://images.brickset.com/sets/images/71309-1...
# 607   237.0     19.99  http://images.brickset.com/sets/images/70312-1...
# 610    33.0     14.99  http://images.brickset.com/sets/images/71241-1...
# 616    63.0      4.99                                                NaN
# 617     NaN     19.99                                                NaN
#
#      quantity
# 1           1
# 2           1
# 27          1
# 28          2
# 29          1
# ..        ...
# 606         2
# 607         2
# 610         3
# 616         2
# 617         1
#
# [183 rows x 14 columns]

# %%
mask4 = (DF['age'] >= 36) & (DF['age'] <= 50)
DF[mask4]
# Out:
#     first_name       last_name  age  phone_number  set_id number  \
# 3      Chelsea        Bouchard   41           NaN   24695  31048
# 4      Chelsea        Bouchard   41           NaN   25626  70595
# 5      Chelsea        Bouchard   41           NaN   24721  10831
# 8        Caleb  Garcia-Wideman   37  907-555-9236   24730  41115
# 9        Caleb  Garcia-Wideman   37  907-555-9236   25611  21127
# ..         ...             ...  ...           ...     ...    ...
# 598     Payton          Milsap   42           NaN   24702  76063
# 599     Payton          Milsap   42           NaN   24678  60109
# 602  Stephanie        Harrison   42           NaN   24736  41121
# 618     Amelia         Hageman   40  336-555-1950   24702  76063
# 619     Amelia         Hageman   40  336-555-1950   24720  10830
#
#                       theme              subtheme  year  \
# 3                   Creator                   NaN  2018
# 4                   Ninjago  Rise of the Villains  2018
# 5                     Duplo                   NaN  2018
# 8                   Friends                   NaN  2018
# 9                 Minecraft         Minifig-scale  2018
# ..                      ...                   ...   ...
# 598  DC Comics Super Heroes         Mighty Micros  2018
# 599                    City                  Fire  2018
# 602                 Friends        Adventure Camp  2018
# 618  DC Comics Super Heroes         Mighty Micros  2018
# 619                   Duplo                   NaN  2018
#
#                            name  pieces  us_price  \
# 3                Lakeside Lodge   368.0     29.99
# 4          Ultra Stealth Raider  1093.0    119.99
# 5          My First Caterpillar    19.0      9.99
# 8      Emma's Creative Workshop   108.0      9.99
# 9                  The Fortress     NaN    109.99
# ..                          ...     ...       ...
# 598  The Flash vs. Captain Cold    88.0      9.99
# 599                   Fire Boat   412.0     79.99
# 602      Adventure Camp Rafting   320.0     29.99
# 618  The Flash vs. Captain Cold    88.0      9.99
# 619               Minnie's Café    27.0     19.99
#
#                                              image_url  quantity
# 3    http://images.brickset.com/sets/images/31048-1...         1
# 4    http://images.brickset.com/sets/images/70595-1...         1
# 5    http://images.brickset.com/sets/images/10831-1...         1
# 8    http://images.brickset.com/sets/images/41115-1...         1
# 9    http://images.brickset.com/sets/images/21127-1...         2
# ..                                                 ...       ...
# 598  http://images.brickset.com/sets/images/76063-1...         3
# 599  http://images.brickset.com/sets/images/60109-1...         2
# 602  http://images.brickset.com/sets/images/41121-1...         1
# 618  http://images.brickset.com/sets/images/76063-1...         2
# 619  http://images.brickset.com/sets/images/10830-1...         4
#
# [216 rows x 14 columns]

# %%
mask5 = DF['age'] >= 50
DF[mask5]
# Out:
#     first_name      last_name  age  phone_number  set_id number       theme  \
# 31      Hannah  Drews Stunkel   55  339-555-6320   25628  70590     Ninjago
# 32      Hannah  Drews Stunkel   55  339-555-6320   25624  70593     Ninjago
# 33      Hannah  Drews Stunkel   55  339-555-6320   24734  41119     Friends
# 38       Riley            Ott   51  517-555-2093   24785  75126   Star Wars
# 39       Riley            Ott   51  517-555-2093   24772  70604     Ninjago
# ..         ...            ...  ...           ...     ...    ...         ...
# 564      Elias        Garrett   50  832-555-9165   25898  75145   Star Wars
# 565      Elias        Garrett   50  832-555-9165   24725  41174       Elves
# 594     Dustin      Vanvuuren   51  812-555-1009   24709  10803       Duplo
# 595     Dustin      Vanvuuren   51  812-555-1009   24807  71235  Dimensions
# 596     Dustin      Vanvuuren   51  812-555-1009   25920  75151   Star Wars
#
#              subtheme  year                       name  pieces  us_price  \
# 31                NaN  2018    Airjitzu Battle Grounds   666.0     59.99
# 32           Skybound  2018       The Green NRG Dragon   567.0     49.99
# 33                NaN  2018     Heartlake Cupcake Cafe   439.0     39.99
# 38      MicroFighters  2018    First Order Snowspeeder    91.0      9.99
# 39           Skybound  2018         Tiger Widow Island   450.0     49.99
# ..                ...   ...                        ...     ...       ...
# 564  Original Content  2018            Eclipse Fighter   363.0     29.99
# 565               NaN  2018          The Starlight Inn   343.0     29.99
# 594               NaN  2018                     Arctic    40.0     29.99
# 595        Level Pack  2018  Level Pack: Midway Arcade    96.0     29.99
# 596       Episode III  2018           Clone Turbo Tank   903.0    109.99
#
#                                              image_url  quantity
# 31                                                 NaN         1
# 32   http://images.brickset.com/sets/images/70593-1...         3
# 33   http://images.brickset.com/sets/images/41119-1...         1
# 38   http://images.brickset.com/sets/images/75126-1...         2
# 39   http://images.brickset.com/sets/images/70604-1...         1
# ..                                                 ...       ...
# 564  http://images.brickset.com/sets/images/75145-1...         1
# 565  http://images.brickset.com/sets/images/41174-1...         1
# 594  http://images.brickset.com/sets/images/10803-1...         2
# 595  http://images.brickset.com/sets/images/71235-1...         1
# 596  http://images.brickset.com/sets/images/75151-1...         1
#
# [75 rows x 14 columns]

# %%
DF_group.groupby(by=['number']).sum()
# Out:
#         first_name          last_name  age  phone_number  set_id  \
# number
# 10803      Michael             Donner   18  432-555-3069   24709
# 10814      Natalia           Vonduyke   16  859-555-3818   24714
# 30347       Steven         Washington   16  336-555-1433   25910
# 30349       Steven         Washington   16  336-555-1433   25893
# 31043        Lucas  Jimenez-Dominguez   18  712-555-0459   24691
# 31046     Michelle          Uguccioni   17             0   24896
# 40201       Serena         Bartkowiak   16  305-555-2377   24987
# 41140        Lucas  Jimenez-Dominguez   18  712-555-0459   24704
# 41172      Michael               Cruz   17  361-555-8212   24723
# 41556       Talise           Nieukirk   16  801-555-2343   24902
# 41558        Lucas  Jimenez-Dominguez   18  712-555-0459   24903
# 41572        Lucas  Jimenez-Dominguez   18  712-555-0459   26033
# 41573        Lucas  Jimenez-Dominguez   18  712-555-0459   26034
# 5005060    Michael             Donner   18  432-555-3069   26059
# 60109     Chayanne           Williams   17  869-555-6681   24678
# 60111        Aaron             Bruner   18  914-555-5003   24679
# 70310     Michelle          Uguccioni   17             0   24756
# 70332      Natalia           Vonduyke   16  859-555-3818   24765
# 70605      Michael               Cruz   17  361-555-8212   24920
# 71238      Michael               Cruz   17  361-555-8212   24618
# 71241      Michael             Donner   18  432-555-3069   24660
# 71300        Aaron             Bruner   18  914-555-5003   24956
# 71311       Serena         Bartkowiak   16  305-555-2377   24806
# 71314        Dylan            Mcgrath   18  229-555-1970   25645
# 75113       Serena         Bartkowiak   16  305-555-2377   24778
# 75137        Aaron             Bruner   18  914-555-5003   24796
# 75149      Natalia           Vonduyke   16  859-555-3818   25922
# 76044     Chayanne           Williams   17  869-555-6681   24697
# 76050        Dylan            Mcgrath   18  229-555-1970   24748
# 853534     Natalia           Vonduyke   16  859-555-3818   25879
#
#                           theme                            subtheme  year  \
# number
# 31046    http://images.brickset.com/sets/images/31046-1...         1
# 40201    http://images.brickset.com/sets/images/40201-1...         1
# 41140    http://images.brickset.com/sets/images/41140-1...         1
# 41172    http://images.brickset.com/sets/images/41172-1...         1
# 41556    http://images.brickset.com/sets/images/41556-1...         2
# 41558    http://images.brickset.com/sets/images/41558-1...         2
# 41572                                                    0         1
# 41573                                                    0         1
# 5005060  http://images.brickset.com/sets/images/5005060...         1
# 60109    http://images.brickset.com/sets/images/60109-1...         2
# 60111    http://images.brickset.com/sets/images/60111-1...         4
# 70310    http://images.brickset.com/sets/images/70310-1...         1
# 70332    http://images.brickset.com/sets/images/70332-1...         1
# 70605    http://images.brickset.com/sets/images/70605-1...         1
# 71238    http://images.brickset.com/sets/images/71238-1...         1
# 71241    http://images.brickset.com/sets/images/71241-1...         2
# 71300    http://images.brickset.com/sets/images/71300-1...         1
# 71311    http://images.brickset.com/sets/images/71311-1...         2
# 71314                                                    0         1
# 75113    http://images.brickset.com/sets/images/75113-1...         1
# 75137    http://images.brickset.com/sets/images/75137-1...         2
# 75149    http://images.brickset.com/sets/images/75149-1...         1
# 76044    http://images.brickset.com/sets/images/76044-1...         1
# 76050    http://images.brickset.com/sets/images/76050-1...         1
# 853534   http://images.brickset.com/sets/images/853534-...         2

# %%
DF_group.groupby(by=['number']).max()

# %% [markdown]
# ### Exercises
#
# * Answer the following questions using reproducible Python code.
# * For each question, state your answer in a sentence, e.g. "In this sample, the first three common names of purchasers are ...".
# * Note that the answers to all questions are within the context of this particular sample of sales, i.e. you shouldn't make inferences about the population of all Lego sales based on this sample.
#
# -------------
#
# 1.  Describe what you see in the data set (variables, observations, etc)
#
# 2.  What are the three most common first names of purchasers?
#
# 3.  What are the three most common themes of Lego sets purchased?
#
# 4.  Among the most common theme of Lego sets purchased, what is the most common subtheme?
#
# 5.  Create data frames for each of the ages in the following categories: "18 and under", "19 - 25", "26 - 35", "36 - 50", "51 and over". HINT - use masks and create separate data frames -OR- create a new column with these categorical labels (more advanced).
#
# 6.  Which age group has purchased the highest number of Lego sets.
#
# 7.  Which age group has spent the most money on Legos?
#
# 8.  Which Lego theme has made the most money for Lego? HINT: Simpler than #5, just use a groupby()
#
# 9.  Which area code has spent the most money on Legos? In the US the area code is the first 3 digits of a phone number. HINT: You will need to split the phone number and get just the first three. You decided what to do about reporting the NaNs.
#
# 10.  Come up with a question you want to answer using these data, and write it down. Then, create a data visualization that answers the question, and explain how your visualization answers the question.

# %% [markdown]
# 1. There are 620 observations and 14 variables. it's made up of a mix of numerical and categorical data.
# 2. Jackson, Joseph, and Jacob seem to be the three most common names.
# 3. The three most common lego types being purchased are the Star wars, Nexo knight, and gear/mixels.
# 4. nexo Knights is the most common subtheme of lego sets purchased.
# 5.

# %% [markdown]
# ## Essay Response
#
# Give a brief report on what you are reading and what you have learned so far. If you chose your own articles please insert a link to the articles. If you chose a book, please give the book title and author.
#
# 1. What drew you to the book/articles
# 2. What have you learned so far.
#
# eg. In the first chapter of the book the author talks about..... or My first article discusses..... or I disagree with what the author is saying so far.... or I really like what I am learning about because....
